# %%
credit_data_sample<- read.csv("M:\\Imarticus\\ProjectR\\Credit card fraud\\Datafiles\\credit_data_sample.csv", header = TRUE,
                              stringsAsFactors = TRUE,
                              strip.white = FALSE ,
                              sep = ',')

# %%
credit_data_sample$Class= as.factor(credit_data_sample$Class)

library(party)
library(partykit)

credit_ctree <- ctree(Class ~., data=credit_data_sample)
credit_ctree1 <- ctree(Class ~V4+V10+V12+V14, data=credit_data_sample)
credit_ctree
# Out:
# Loading required package: grid
# Loading required package: mvtnorm
# Loading required package: modeltools
# Loading required package: stats4
# Loading required package: strucchange
# Loading required package: zoo
#
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# Loading required package: libcoin
#
# Attaching package: 'partykit'
#
# The following objects are masked from 'package:party':
#
#     cforest, ctree, ctree_control, edge_simple, mob, mob_control,
#     node_barplot, node_bivplot, node_boxplot, node_inner, node_surv,
#     node_terminal, varimp
# Model formula:
# Class ~ Time + V1 + V2 + V3 + V4 + V5 + V6 + V7 + V8 + V9 + V10 +
#     V11 + V12 + V13 + V14 + V15 + V16 + V17 + V18 + V19 + V20 +
#     V21 + V22 + V23 + V24 + V25 + V26 + V27 + V28 + Amount
#
# Fitted party:
# [1] root
# |   [2] V14 <= -2.95382
# |   |   [3] V4 <= -0.07394: 1 (n = 7, err = 42.9%)
# ...

# %%
plot(as.simpleparty(credit_ctree), type="simple")
# Out:
# plot without title

# %%
plot(as.simpleparty(credit_ctree1), type="simple")
# Out:
# plot without title

# %%
library(tree)
credit_tree <- tree(Class ~., data=credit_data_sample)
plot(credit_tree)
text(credit_tree)
# Out:
# plot without title

# %%
library(rpart)
library(rattle)

rpart <- rpart(Class ~., data=credit_data_sample, method="class")
fancyRpartPlot(rpart)
# Out:
# Rattle: A free graphical interface for data science with R.
# Version 5.2.0 Copyright (c) 2006-2018 Togaware Pty Ltd.
# Type 'rattle()' to shake, rattle, and roll your data.
# Plot with title ""

# %%
#conclusion as per decision Tree Model
# 1. V4,V14 & V17 may be imporatant variables for classification of Class variable
